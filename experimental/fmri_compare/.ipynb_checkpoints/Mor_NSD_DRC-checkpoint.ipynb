# %%
from import_data_utils import *
sub = 2
cutims, voxels_ROIs_full = import_data_for_sub(sub, path)

# %%
# Ecog
with open('/home/mor/ECoG/subjects_data/RDMv_GBL_dist10.pkl', 'rb') as f:
    RDM_ecog= pkl.load(f)

with open('/home/mor/ECoG/subjects_data/all_images.pkl', 'rb') as f:
    cutims= pkl.load(f)

# RDMv, all_images

cutims = cv2.normalize(cutims, None, alpha = 0, beta = 255, norm_type = cv2.NORM_MINMAX, dtype = cv2.CV_32F)
cutims = cutims.astype(np.uint8)

# %%
RDM_ecog
# Out:
# {'V1': array([[0.00000000e+00, 3.10342887e-01, 8.51089668e-02, ...,
#          2.04282442e-01, 5.73858911e-01, 2.82469733e-01],
#         [3.10342887e-01, 2.22044605e-16, 4.61359074e-01, ...,
#          5.90679640e-01, 7.75485405e-01, 3.46525993e-01],
#         [8.51089668e-02, 4.61359074e-01, 2.22044605e-16, ...,
#          2.20331364e-01, 3.73805592e-01, 4.70378062e-01],
#         ...,
#         [2.04282442e-01, 5.90679640e-01, 2.20331364e-01, ...,
#          0.00000000e+00, 4.80902664e-01, 3.53611381e-01],
#         [5.73858911e-01, 7.75485405e-01, 3.73805592e-01, ...,
#          4.80902664e-01, 0.00000000e+00, 6.77779639e-01],
#         [2.82469733e-01, 3.46525993e-01, 4.70378062e-01, ...,
#          3.53611381e-01, 6.77779639e-01, 0.00000000e+00]]),
#  'V2': array([[0.        , 0.29389862, 0.22801204, ..., 0.5650088 , 0.50350513,
#          0.37149122],
#         [0.29389862, 0.        , 0.21994235, ..., 0.33729086, 0.43582888,
#          0.40416637],
#         [0.22801204, 0.21994235, 0.        , ..., 0.37001203, 0.48009616,
#          0.36406092],
#         ...,
#         [0.5650088 , 0.33729086, 0.37001203, ..., 0.        , 0.5024691 ,
#          0.38080576],
#         [0.50350513, 0.43582888, 0.48009616, ..., 0.5024691 , 0.        ,
#          0.34534508],
#         [0.37149122, 0.40416637, 0.36406092, ..., 0.38080576, 0.34534508,
#          0.        ]])}

# %%
# internal imports for RDC
sys.path.insert(1, '../../')
from utils.imagenet_dataset import get_dataset
from utils.image_processing import preprocess_image_drc
from models.student_models  import student3
# Out:
# /usr/local/lib/python3.8/dist-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.3.0 and strictly below 2.6.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.6.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
# allocating memory and creating the Keras VGG16 net
gpu_n=3
physical_devices = tf.config.list_physical_devices('GPU')
tf.config.set_visible_devices(physical_devices[gpu_n], 'GPU')
tf.config.experimental.set_memory_growth(physical_devices[gpu_n], True)
# Out:
# 2023-11-13 16:41:55.036830: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-13 16:41:55.037175: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-13 16:41:55.037455: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-13 16:41:55.037727: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-13 16:41:55.059090: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-13 16:41:55.059379: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-13 16:41:55.059654: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-13 16:41:55.059922: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-13 16:41:55.060189: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-13 16:41:55.060451: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-13 16:41:55.060718: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-13 16:41:55.060989: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero

# %% [markdown]
# # Loading files & Pre-processing

# %% [markdown]
# ## Image filtering

# %%
# image resizing and padding
def resize_padding(x, des_size):
    """
    This function takes the image which is already in the desired size, but minimizes it to a smaller size
    and add padding to keep the original size.  
    """
    if x.shape[0] < des_size:
        raise ValueError("Desired size must be smaller than original size!")
    neutral_color = x[0,0,0]  #pixel from the image surrounding
    padding = np.ones(x.shape) * neutral_color
    start =(x.shape[0] - des_size)//2
    end = start + des_size
    resized_im = keras.layers.Resizing(des_size, des_size, interpolation='bilinear', crop_to_aspect_ratio=False,)(x).numpy()
    padding[start:end, start:end] = resized_im
    return padding

# %%
#zoomin 
def zoomin_img(img, zoomsize):
    """
    This function will zoom in the image by increasing it to a bigger size and then cut and use only the middle square of it 
    to enter the network.
    
    img: an image which is already the desired size!
    zoomin = the new bigger size which we will zoom into
    """
    origin_sz = img.shape[0]
    cut = (zoomsize-origin_sz)//2
    newim = keras.layers.Resizing(zommin, zommin, interpolation='bilinear', crop_to_aspect_ratio=False,)(img).numpy()
    cutnewim = newim[cut:origin_sz+cut,cut:origin_sz+cut]
    return cutnewim

# %%
# Net parameters
net_size = 224
# batch_size = 64
batch_size = 50
amp_list = [0,2,4,12,18,27]
# amp_list = [12]
net_lim = (len(cutims) // batch_size) * batch_size

# %% [markdown]
# ### examples of pictures filtering

# %%
fig, axs = plt.subplots(2,2, figsize=(12, 6))
im1_sub1= cutims[1]
axs[0][0].imshow(im1_sub1, vmin=0, vmax=255)
#example of image cutting

#example of image blurring
im1_blur = cv2.blur(im1_sub1,(7,7))
axs[0][1].imshow(im1_blur.astype(int))

# example of the resizing the picture and adding paddings.
img = keras.layers.Resizing(224, 224, interpolation='bilinear', crop_to_aspect_ratio=False,)(im1_sub1).numpy()
new_size = 100
img_res = resize_padding(img, new_size)
axs[1][0].imshow(img_res.astype(int), vmin=0, vmax=255)

#zoomin 
a = img
zommin = int(224*1.6)
origin_sz = 224
# cut = (zommin-origin_sz)//2
# a1 = keras.layers.Resizing(zommin, zommin, interpolation='bilinear', crop_to_aspect_ratio=False,)(a).numpy()
# a2 = a1[cut:zommin-cut,cut:zommin-cut]

a2 = zoomin_img(img,zommin)
axs[1][1].imshow(a2.astype(int), vmin=0, vmax=255)
# Out:
# 2023-11-13 16:41:55.238852: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-13 16:41:55.239238: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-13 16:41:55.239536: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-13 16:41:55.580221: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-13 16:41:55.580540: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-13 16:41:55.580818: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-13 16:41:55.581075: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1189 MB memory:  -> device: 3, name: NVIDIA RTX A6000, pci bus id: 0000:61:00.0, compute capability: 8.6

# %% [raw]
# # Example Voxels Bold signal from voxels_vis_ROIS V1 ventral
# fig, ax = plt.subplots(figsize=(12, 5))
# ax.set(xlabel="Voxel", ylabel="Stimulus")
# heatmap = ax.imshow(voxels_ROIs_full['prf-visualrois']['V1v'],
#                     aspect="auto", vmin=-1, vmax=1, cmap="bwr")
# fig.colorbar(heatmap, shrink=.5, label="Response amplitude (Z)")
# fig.tight_layout()
# fig.show()

# %% [raw]
# # calculate RDM for fmri data
# RDM_fmri = {}
# for area in voxels_ROIs_full.keys():
#     RDM_fmri[area] = {}
#     for roi in voxels_ROIs_full[area].keys():
#         RDM_fmri[area][roi] = 1-np.corrcoef(voxels_ROIs_full[area][roi][:net_lim,:])
#     print("Created RDM for: " + str(area))

# %% [markdown]
# # Applying VGG16

# %%
class pic_edit():
    """
    This class should ease applying filters and edits to the cut squered pictue before they are being proccessed by the net. 
    It aims to contain all present and future potential dynamic properties of a picture.
    """
    def __init__(self, size = 224, blur = 1):
        self.size = size
        self.blur = blur
        
    def __repr__(self):
        return f'pic({self.size, self.blur})'
    
    def __hash__(self):
        return hash((self.size, self.blur))
    
d = {pic_edit(224,1) :1}

# %%
# Bulilding Net

def preprocss_net(input_size, cut_ims, pic_params):
    """
    This function exectute all needed and optional steps before implementing the network over the data
    it resizes the input, and when needed it decreses and creates padding
    """ 
    input_len = len(cut_ims)
    input_net = np.zeros((input_len, input_size, input_size,3))
    for i in range(input_len):       
        input_net[i] = keras.layers.Resizing(input_size, input_size, interpolation='bilinear', crop_to_aspect_ratio=False,)(cut_ims[i]).numpy()
        if pic_params.blur > 0:
            input_net[i] = cv2.blur(input_net[i], (pic_params.blur, pic_params.blur))
        if pic_params.size < input_size:
            input_net[i] = resize_padding(input_net[i], pic_params.size)
        elif pic_params.size > input_size:
            cut = (pic_params.size-net_size)//2
            zoomin = keras.layers.Resizing(pic_params.size, pic_params.size, interpolation='bilinear', crop_to_aspect_ratio=False,)(input_net[i]).numpy()
            cutzoom = zoomin[cut:net_size+cut,cut:net_size+cut]
            if i < 1:
                plt.imshow(cutzoom.astype(int), vmin=0, vmax=255)
                plt.show()
            input_net[i] = cutzoom
    input_net = input_net[:net_lim,...]
    input_net = input_net * (1/256)
    return input_net

# %%
# input_net.shape

# %% [markdown]
# ### DRC

# %%
def preprocess_for_drc_image(x,**kwargs):
    low_res_frames, _ = preprocess_image_drc(x, x.shape[-2], kwargs['res'], is_training=False,teacher_mode=False,**kwargs)
    return low_res_frames

def preprocess_for_drc_batch(x, **kwargs):
    s = np.shape(x)
    n_steps = kwargs['n_steps']
    res = kwargs['res']
    xout = np.zeros([s[0],n_steps,res,res,s[-1]])
    for ii, this_image in enumerate(x):
        xout[ii] = preprocess_for_drc_image(tf.convert_to_tensor(this_image,dtype=tf.float32),**kwargs)
    return xout

# %%
drc_args=dict(preprocessing='default',rggb_mode=False,
              return_position_info=False, offsets = None,
              unprocess_high_res=False,enable_random_gains=False,n_steps=5,res=56,
              central_squeeze_and_pad_factor=-1)

drc_fe_args = {'sample': 5, 'res': 56, 'activation': 'relu', 'dropout': 0.0, 
               'rnn_dropout': 0.0, 'num_features': 128, 'rnn_layer1': 32, 'rnn_layer2': 64, 
               'layer_norm': False, 'batch_norm': False, 'conv_rnn_type': 'lstm', 
               'block_size': 1, 'add_coordinates': 0, 'time_pool': 'average_pool', 'dense_interface': True,
               'loss': 'mean_squared_error', 'upsample': 0, 'pos_det': None, 'enable_inputB': False,
               'expanded_inputB': False, 'rggb_ext_type': 0, 'channels': 3, 'updwn': 1,
               'kernel_size': 3, 'custom_metrics': []}

parameters = {}

parameters['pretrained_student_path'] = '/home/arivkind/pretrained_models/vgg16drc_baseline/noname_j1131336_t1662126871_feature_net_ckpt'
parameters['pretrained_decoder_path'] = '/home/arivkind/pretrained_models/vgg16drc_baseline/noname_j1131336_t1662126871_saved_models/decoder_trained_model_fix0/'

# %%
student = student3(**drc_fe_args)
student.summary()
# Out:
# (None, 5, 56, 56, 3)
# True
# average_pool
# (None, 56, 56, 128)
# Model: "student_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 5, 56, 56, 3)]    0
# _________________________________________________________________
# convLSTM10 (ConvLSTM2D)      (None, 5, 56, 56, 32)     40448
# _________________________________________________________________
# convLSTM20 (ConvLSTM2D)      (None, 5, 56, 56, 64)     221440
# _________________________________________________________________
# convLSTM30 (ConvLSTM2D)      (None, 5, 56, 56, 128)    885248
# _________________________________________________________________
# time_distributed (TimeDistri (None, 5, 56, 56, 128)    147584
# _________________________________________________________________
# average_pooling3d (AveragePo (None, 1, 56, 56, 128)    0
# _________________________________________________________________
# tf.compat.v1.squeeze (TFOpLa (None, 56, 56, 128)       0
# =================================================================
# Total params: 1,294,720
# Trainable params: 1,294,720
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.8/dist-packages/keras/optimizer_v2/optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(

# %%
load_status1 = student.load_weights(parameters['pretrained_student_path'])
decoder2 = keras.models.load_model(parameters['pretrained_decoder_path'])
# Out:
# 2023-11-13 16:42:06.124917: W tensorflow/core/common_runtime/bfc_allocator.cc:463] Allocator (GPU_0_bfc) ran out of memory trying to allocate 392.00MiB (rounded to 411041792)requested by op AddV2
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2023-11-13 16:42:06.125009: I tensorflow/core/common_runtime/bfc_allocator.cc:1013] BFCAllocator dump for GPU_0_bfc
# 2023-11-13 16:42:06.125034: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (256): 	Total Chunks: 26, Chunks in use: 26. 6.5KiB allocated for chunks. 6.5KiB in use in bin. 112B client-requested in use in bin.
# 2023-11-13 16:42:06.125053: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (512): 	Total Chunks: 6, Chunks in use: 6. 3.0KiB allocated for chunks. 3.0KiB in use in bin. 3.0KiB client-requested in use in bin.
# 2023-11-13 16:42:06.125070: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (1024): 	Total Chunks: 7, Chunks in use: 7. 7.8KiB allocated for chunks. 7.8KiB in use in bin. 7.0KiB client-requested in use in bin.
# 2023-11-13 16:42:06.125088: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (2048): 	Total Chunks: 9, Chunks in use: 9. 18.5KiB allocated for chunks. 18.5KiB in use in bin. 18.0KiB client-requested in use in bin.
# 2023-11-13 16:42:06.125105: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (4096): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-13 16:42:06.125122: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (8192): 	Total Chunks: 2, Chunks in use: 2. 27.0KiB allocated for chunks. 27.0KiB in use in bin. 27.0KiB client-requested in use in bin.
# 2023-11-13 16:42:06.125139: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (16384): 	Total Chunks: 1, Chunks in use: 1. 19.8KiB allocated for chunks. 19.8KiB in use in bin. 13.5KiB client-requested in use in bin.
# 2023-11-13 16:42:06.125155: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (32768): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-13 16:42:06.125170: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (65536): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-13 16:42:06.125188: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (131072): 	Total Chunks: 4, Chunks in use: 3. 680.0KiB allocated for chunks. 432.0KiB in use in bin. 432.0KiB client-requested in use in bin.
# 2023-11-13 16:42:06.125205: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (262144): 	Total Chunks: 3, Chunks in use: 3. 864.0KiB allocated for chunks. 864.0KiB in use in bin. 864.0KiB client-requested in use in bin.
# 2023-11-13 16:42:06.125222: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (524288): 	Total Chunks: 8, Chunks in use: 6. 4.60MiB allocated for chunks. 3.38MiB in use in bin. 3.38MiB client-requested in use in bin.
# 2023-11-13 16:42:06.125238: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (1048576): 	Total Chunks: 4, Chunks in use: 4. 4.50MiB allocated for chunks. 4.50MiB in use in bin. 4.50MiB client-requested in use in bin.
# 2023-11-13 16:42:06.125255: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (2097152): 	Total Chunks: 7, Chunks in use: 5. 15.75MiB allocated for chunks. 11.25MiB in use in bin. 11.25MiB client-requested in use in bin.
# 2023-11-13 16:42:06.125272: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (4194304): 	Total Chunks: 1, Chunks in use: 1. 4.50MiB allocated for chunks. 4.50MiB in use in bin. 4.50MiB client-requested in use in bin.
# 2023-11-13 16:42:06.125289: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (8388608): 	Total Chunks: 7, Chunks in use: 5. 63.00MiB allocated for chunks. 45.00MiB in use in bin. 45.00MiB client-requested in use in bin.
# 2023-11-13 16:42:06.125304: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-13 16:42:06.125321: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-13 16:42:06.125331: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-13 16:42:06.125344: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-13 16:42:06.125352: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (268435456): 	Total Chunks: 3, Chunks in use: 2. 1.07GiB allocated for chunks. 784.00MiB in use in bin. 784.00MiB client-requested in use in bin.
# 2023-11-13 16:42:06.125359: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] Bin for 392.00MiB was 256.00MiB, Chunk State:
# 2023-11-13 16:42:06.125371: I tensorflow/core/common_runtime/bfc_allocator.cc:1042]   Size: 311.07MiB | Requested Size: 0B | in_use: 0 | bin_num: 20, prev:   Size: 392.00MiB | Requested Size: 392.00MiB | in_use: 1 | bin_num: -1
# 2023-11-13 16:42:06.125378: I tensorflow/core/common_runtime/bfc_allocator.cc:1049] Next region of size 1246756864
# 2023-11-13 16:42:06.125388: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50000000 of size 256 next 4
# 2023-11-13 16:42:06.125395: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50000100 of size 256 next 3
# 2023-11-13 16:42:06.125401: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50000200 of size 256 next 5
# 2023-11-13 16:42:06.125408: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50000300 of size 256 next 6
# 2023-11-13 16:42:06.125414: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50000400 of size 256 next 11
# 2023-11-13 16:42:06.125421: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50000500 of size 256 next 12
# 2023-11-13 16:42:06.125427: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50000600 of size 256 next 13
# 2023-11-13 16:42:06.125434: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50000700 of size 256 next 14
# 2023-11-13 16:42:06.125440: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50000800 of size 256 next 15
# 2023-11-13 16:42:06.125447: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50000900 of size 512 next 16
# 2023-11-13 16:42:06.125453: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50000b00 of size 256 next 21
# 2023-11-13 16:42:06.125460: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50000c00 of size 256 next 27
# 2023-11-13 16:42:06.125466: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50000d00 of size 256 next 20
# 2023-11-13 16:42:06.125473: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50000e00 of size 256 next 28
# 2023-11-13 16:42:06.125479: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50000f00 of size 256 next 19
# 2023-11-13 16:42:06.125486: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50001000 of size 1024 next 30
# 2023-11-13 16:42:06.125492: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50001400 of size 256 next 31
# 2023-11-13 16:42:06.125499: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50001500 of size 256 next 32
# 2023-11-13 16:42:06.125505: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50001600 of size 256 next 33
# 2023-11-13 16:42:06.125512: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50001700 of size 256 next 26
# 2023-11-13 16:42:06.125518: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50001800 of size 256 next 22
# 2023-11-13 16:42:06.125524: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50001900 of size 256 next 61
# 2023-11-13 16:42:06.125531: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50001a00 of size 1536 next 25
# 2023-11-13 16:42:06.125538: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50002000 of size 20224 next 7
# 2023-11-13 16:42:06.125607: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50006f00 of size 1024 next 9
# 2023-11-13 16:42:06.125614: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50007300 of size 2048 next 58
# 2023-11-13 16:42:06.125621: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50007b00 of size 1024 next 66
# 2023-11-13 16:42:06.125627: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50007f00 of size 256 next 67
# 2023-11-13 16:42:06.125634: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50008000 of size 256 next 68
# 2023-11-13 16:42:06.125640: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50008100 of size 2048 next 69
# 2023-11-13 16:42:06.125647: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50008900 of size 256 next 72
# 2023-11-13 16:42:06.125653: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50008a00 of size 256 next 73
# 2023-11-13 16:42:06.125659: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50008b00 of size 2048 next 76
# 2023-11-13 16:42:06.125666: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50009300 of size 2048 next 78
# 2023-11-13 16:42:06.125673: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50009b00 of size 2560 next 8
# 2023-11-13 16:42:06.125679: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e5000a500 of size 13824 next 34
# 2023-11-13 16:42:06.125686: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e5000db00 of size 512 next 37
# 2023-11-13 16:42:06.125692: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e5000dd00 of size 512 next 38
# 2023-11-13 16:42:06.125699: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e5000df00 of size 1024 next 41
# 2023-11-13 16:42:06.125705: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e5000e300 of size 1024 next 42
# 2023-11-13 16:42:06.125712: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e5000e700 of size 2048 next 47
# 2023-11-13 16:42:06.125718: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e5000ef00 of size 2048 next 48
# 2023-11-13 16:42:06.125725: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e5000f700 of size 512 next 51
# 2023-11-13 16:42:06.125731: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e5000f900 of size 512 next 52
# 2023-11-13 16:42:06.125738: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e5000fb00 of size 512 next 53
# 2023-11-13 16:42:06.125744: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e5000fd00 of size 13824 next 54
# 2023-11-13 16:42:06.125751: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50013300 of size 2048 next 81
# 2023-11-13 16:42:06.125757: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50013b00 of size 2048 next 83
# 2023-11-13 16:42:06.125764: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50014300 of size 256 next 84
# 2023-11-13 16:42:06.125770: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50014400 of size 256 next 85
# 2023-11-13 16:42:06.125777: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] Free  at 7f6e50014500 of size 253952 next 10
# 2023-11-13 16:42:06.125783: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50052500 of size 147456 next 35
# 2023-11-13 16:42:06.125790: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50076500 of size 147456 next 36
# 2023-11-13 16:42:06.125796: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e5009a500 of size 294912 next 18
# 2023-11-13 16:42:06.125803: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] Free  at 7f6e500e2500 of size 543232 next 1
# 2023-11-13 16:42:06.125809: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50166f00 of size 1280 next 2
# 2023-11-13 16:42:06.125816: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50167400 of size 589824 next 17
# 2023-11-13 16:42:06.125823: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e501f7400 of size 294912 next 39
# 2023-11-13 16:42:06.125830: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e5023f400 of size 147456 next 55
# 2023-11-13 16:42:06.125836: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] Free  at 7f6e50263400 of size 737280 next 29
# 2023-11-13 16:42:06.125843: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50317400 of size 589824 next 40
# 2023-11-13 16:42:06.125849: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e503a7400 of size 589824 next 24
# 2023-11-13 16:42:06.125856: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] Free  at 7f6e50437400 of size 2359296 next 62
# 2023-11-13 16:42:06.125862: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50677400 of size 1179648 next 23
# 2023-11-13 16:42:06.125869: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50797400 of size 1179648 next 43
# 2023-11-13 16:42:06.125875: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e508b7400 of size 1179648 next 44
# 2023-11-13 16:42:06.125882: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e509d7400 of size 2359296 next 45
# 2023-11-13 16:42:06.125888: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50c17400 of size 2359296 next 46
# 2023-11-13 16:42:06.125895: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50e57400 of size 589824 next 49
# 2023-11-13 16:42:06.125901: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50ee7400 of size 589824 next 50
# 2023-11-13 16:42:06.125908: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50f77400 of size 294912 next 56
# 2023-11-13 16:42:06.125914: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e50fbf400 of size 589824 next 57
# 2023-11-13 16:42:06.125921: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e5104f400 of size 1179648 next 59
# 2023-11-13 16:42:06.125927: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e5116f400 of size 2359296 next 60
# 2023-11-13 16:42:06.125934: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] Free  at 7f6e513af400 of size 2359296 next 64
# 2023-11-13 16:42:06.125940: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e515ef400 of size 2359296 next 63
# 2023-11-13 16:42:06.125947: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e5182f400 of size 2359296 next 65
# 2023-11-13 16:42:06.125953: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] Free  at 7f6e51a6f400 of size 9437184 next 71
# 2023-11-13 16:42:06.125960: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e5236f400 of size 4718592 next 70
# 2023-11-13 16:42:06.125966: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] Free  at 7f6e527ef400 of size 9437184 next 75
# 2023-11-13 16:42:06.125973: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e530ef400 of size 9437184 next 74
# 2023-11-13 16:42:06.125980: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e539ef400 of size 9437184 next 77
# 2023-11-13 16:42:06.125986: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e542ef400 of size 9437184 next 79
# 2023-11-13 16:42:06.125993: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e54bef400 of size 9437184 next 80
# 2023-11-13 16:42:06.125999: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e554ef400 of size 9437184 next 82
# 2023-11-13 16:42:06.126006: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e55def400 of size 411041792 next 86
# 2023-11-13 16:42:06.126012: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7f6e6e5ef400 of size 411041792 next 88
# 2023-11-13 16:42:06.126020: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] Free  at 7f6e86def400 of size 326175744 next 18446744073709551615
# 2023-11-13 16:42:06.126026: I tensorflow/core/common_runtime/bfc_allocator.cc:1074]      Summary of in-use Chunks by size:
# 2023-11-13 16:42:06.126034: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 26 Chunks of size 256 totalling 6.5KiB
# 2023-11-13 16:42:06.126041: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 6 Chunks of size 512 totalling 3.0KiB
# 2023-11-13 16:42:06.126048: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 5 Chunks of size 1024 totalling 5.0KiB
# 2023-11-13 16:42:06.126055: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 1280 totalling 1.2KiB
# 2023-11-13 16:42:06.126062: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 1536 totalling 1.5KiB
# 2023-11-13 16:42:06.126068: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 8 Chunks of size 2048 totalling 16.0KiB
# 2023-11-13 16:42:06.126075: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 2560 totalling 2.5KiB
# 2023-11-13 16:42:06.126082: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 2 Chunks of size 13824 totalling 27.0KiB
# 2023-11-13 16:42:06.126089: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 20224 totalling 19.8KiB
# 2023-11-13 16:42:06.126096: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 3 Chunks of size 147456 totalling 432.0KiB
# 2023-11-13 16:42:06.126103: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 3 Chunks of size 294912 totalling 864.0KiB
# 2023-11-13 16:42:06.126110: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 6 Chunks of size 589824 totalling 3.38MiB
# 2023-11-13 16:42:06.126117: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 4 Chunks of size 1179648 totalling 4.50MiB
# 2023-11-13 16:42:06.126124: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 5 Chunks of size 2359296 totalling 11.25MiB
# 2023-11-13 16:42:06.126131: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 4718592 totalling 4.50MiB
# 2023-11-13 16:42:06.126137: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 5 Chunks of size 9437184 totalling 45.00MiB
# 2023-11-13 16:42:06.126144: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 2 Chunks of size 411041792 totalling 784.00MiB
# 2023-11-13 16:42:06.126151: I tensorflow/core/common_runtime/bfc_allocator.cc:1081] Sum Total of in-use chunks: 853.97MiB
# 2023-11-13 16:42:06.126158: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] total_region_allocated_bytes_: 1246756864 memory_limit_: 1246756864 available bytes: 0 curr_region_allocation_bytes_: 2493513728
# 2023-11-13 16:42:06.126168: I tensorflow/core/common_runtime/bfc_allocator.cc:1089] Stats:
# Limit:                      1246756864
# InUse:                       895453696
# MaxInUse:                    895453952
# NumAllocs:                         170
# MaxAllocSize:                411041792
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2023-11-13 16:42:06.126178: W tensorflow/core/common_runtime/bfc_allocator.cc:474] **************************************************************************__________________________
# 2023-11-13 16:42:06.126199: W tensorflow/core/framework/op_kernel.cc:1680] Resource exhausted: failed to allocate memory
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# /tmp/ipykernel_27395/3673826054.py in <module>
#       1 load_status1 = student.load_weights(parameters['pretrained_student_path'])
# ----> 2 decoder2 = keras.models.load_model(parameters['pretrained_decoder_path'])
#
# /usr/local/lib/python3.8/dist-packages/keras/saving/save.py in load_model(filepath, custom_objects, compile, options)
#     203         filepath = path_to_string(filepath)
#     204         if isinstance(filepath, str):
# --> 205           return saved_model_load.load(filepath, compile, options)
#     206
#     207   raise IOError(
#
# /usr/local/lib/python3.8/dist-packages/keras/saving/saved_model/load.py in load(path, compile, options)
#     132   # Recreate layers and metrics using the info stored in the metadata.
#     133   keras_loader = KerasObjectLoader(metadata, object_graph_def)
# --> 134   keras_loader.load_layers(compile=compile)
#     135
#     136   # Generate a dictionary of all loaded nodes.
#
# /usr/local/lib/python3.8/dist-packages/keras/saving/saved_model/load.py in load_layers(self, compile)
#     392         continue
#     393
# --> 394       self.loaded_nodes[node_metadata.node_id] = self._load_layer(
#     395           node_metadata.node_id, node_metadata.identifier,
#     396           node_metadata.metadata)
#
# /usr/local/lib/python3.8/dist-packages/keras/saving/saved_model/load.py in _load_layer(self, node_id, identifier, metadata)
#     434     # Detect whether this object can be revived from the config. If not, then
#     435     # revive from the SavedModel instead.
# --> 436     obj, setter = self._revive_from_config(identifier, metadata, node_id)
#     437     if obj is None:
#     438       obj, setter = revive_custom_object(identifier, metadata)
#
# /usr/local/lib/python3.8/dist-packages/keras/saving/saved_model/load.py in _revive_from_config(self, identifier, metadata, node_id)
#     452       obj = (
#     453           self._revive_graph_network(identifier, metadata, node_id) or
# --> 454           self._revive_layer_or_model_from_config(metadata, node_id))
#     455
#     456     if obj is None:
#
# /usr/local/lib/python3.8/dist-packages/keras/saving/saved_model/load.py in _revive_layer_or_model_from_config(self, metadata, node_id)
#     554
#     555     build_input_shape = metadata.get('build_input_shape')
# --> 556     built = self._try_build_layer(obj, node_id, build_input_shape)
#     557
#     558     if not built:
#
# /usr/local/lib/python3.8/dist-packages/keras/saving/saved_model/load.py in _try_build_layer(self, obj, node_id, build_input_shape)
#     591
#     592     if build_input_shape is not None:
# --> 593       obj.build(build_input_shape)
#     594       base_layer.Layer.build(obj, build_input_shape)
#     595       return True
#
# /usr/local/lib/python3.8/dist-packages/keras/layers/core.py in build(self, input_shape)
#    1176                        'should be defined. Found `None`.')
#    1177     self.input_spec = InputSpec(min_ndim=2, axes={-1: last_dim})
# -> 1178     self.kernel = self.add_weight(
#    1179         'kernel',
#    1180         shape=[last_dim, self.units],
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py in add_weight(self, name, shape, dtype, initializer, regularizer, trainable, constraint, use_resource, synchronization, aggregation, **kwargs)
#     645         caching_device = None
#     646
# --> 647     variable = self._add_variable_with_custom_getter(
#     648         name=name,
#     649         shape=shape,
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/training/tracking/base.py in _add_variable_with_custom_getter(self, name, shape, dtype, initializer, getter, overwrite, **kwargs_for_getter)
#     811         # "best effort" to set the initializer with the highest restore UID.
#     812         initializer = checkpoint_initializer
# --> 813     new_variable = getter(
#     814         name=name,
#     815         shape=shape,
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/base_layer_utils.py in make_variable(name, shape, dtype, initializer, trainable, caching_device, validate_shape, constraint, use_resource, collections, synchronization, aggregation, partitioner)
#     115   # However, this breaks legacy (Estimator) checkpoints
#     116   # because it changes variable names. Remove this when V1 is fully deprecated.
# --> 117   return tf.compat.v1.Variable(
#     118       initial_value=init_val,
#     119       name=name,
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/variables.py in __call__(cls, *args, **kwargs)
#     264   def __call__(cls, *args, **kwargs):
#     265     if cls is VariableV1:
# --> 266       return cls._variable_v1_call(*args, **kwargs)
#     267     elif cls is Variable:
#     268       return cls._variable_v2_call(*args, **kwargs)
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/variables.py in _variable_v1_call(cls, initial_value, trainable, collections, validate_shape, caching_device, name, variable_def, dtype, expected_shape, import_scope, constraint, use_resource, synchronization, aggregation, shape)
#     210     if aggregation is None:
#     211       aggregation = VariableAggregation.NONE
# --> 212     return previous_getter(
#     213         initial_value=initial_value,
#     214         trainable=trainable,
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/variables.py in <lambda>(**kwargs)
#     203                         shape=None):
#     204     """Call on Variable class. Useful to force the signature."""
# --> 205     previous_getter = lambda **kwargs: default_variable_creator(None, **kwargs)
#     206     for _, getter in ops.get_default_graph()._variable_creator_stack:  # pylint: disable=protected-access
#     207       previous_getter = _make_getter(getter, previous_getter)
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/variable_scope.py in default_variable_creator(next_creator, **kwargs)
#    2610   if use_resource:
#    2611     distribute_strategy = kwargs.get("distribute_strategy", None)
# -> 2612     return resource_variable_ops.ResourceVariable(
#    2613         initial_value=initial_value,
#    2614         trainable=trainable,
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/variables.py in __call__(cls, *args, **kwargs)
#     268       return cls._variable_v2_call(*args, **kwargs)
#     269     else:
# --> 270       return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#     271
#     272
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/resource_variable_ops.py in __init__(self, initial_value, trainable, collections, validate_shape, caching_device, name, dtype, variable_def, import_scope, constraint, distribute_strategy, synchronization, aggregation, shape)
#    1600       self._init_from_proto(variable_def, import_scope=import_scope)
#    1601     else:
# -> 1602       self._init_from_args(
#    1603           initial_value=initial_value,
#    1604           trainable=trainable,
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/resource_variable_ops.py in _init_from_args(self, initial_value, trainable, collections, caching_device, name, dtype, constraint, synchronization, aggregation, distribute_strategy, shape)
#    1738           with ops.name_scope("Initializer"), device_context_manager(None):
#    1739             if init_from_fn:
# -> 1740               initial_value = initial_value()
#    1741             if isinstance(initial_value, trackable.CheckpointInitialValue):
#    1742               self._maybe_initialize_trackable()
#
# /usr/local/lib/python3.8/dist-packages/keras/initializers/initializers_v2.py in __call__(self, shape, dtype, **kwargs)
#     515     else:
#     516       limit = math.sqrt(3.0 * scale)
# --> 517       return self._random_generator.random_uniform(shape, -limit, limit, dtype)
#     518
#     519   def get_config(self):
#
# /usr/local/lib/python3.8/dist-packages/keras/initializers/initializers_v2.py in random_uniform(self, shape, minval, maxval, dtype)
#     970     else:
#     971       op = tf.random.uniform
# --> 972     return op(
#     973         shape=shape, minval=minval, maxval=maxval, dtype=dtype, seed=self.seed)
#     974
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/random_ops.py in random_uniform(shape, minval, maxval, dtype, seed, name)
#     313           result = math_ops.multiply(result, maxval)
#     314       else:
# --> 315         result = math_ops.add(result * (maxval - minval), minval, name=name)
#     316     # TODO(b/132092188): C++ shape inference inside functional ops does not
#     317     # cross FuncGraph boundaries since that information is only available in
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/math_ops.py in add(x, y, name)
#    3941       return gen_math_ops.add(x, y, name=name)
#    3942     else:
# -> 3943       return gen_math_ops.add_v2(x, y, name=name)
#    3944
#    3945
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/gen_math_ops.py in add_v2(x, y, name)
#     453       return _result
#     454     except _core._NotOkStatusException as e:
# --> 455       _ops.raise_from_not_ok_status(e, name)
#     456     except _core._FallbackException:
#     457       pass
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py in raise_from_not_ok_status(e, name)
#    6939   message = e.message + (" name: " + name if name is not None else "")
#    6940   # pylint: disable=protected-access
# -> 6941   six.raise_from(core._status_to_exception(e.code, message), None)
#    6942   # pylint: enable=protected-access
#    6943
#
# /usr/local/lib/python3.8/dist-packages/six.py in raise_from(value, from_value)
#
# ResourceExhaustedError: failed to allocate memory [Op:AddV2]

# %%
net_input = keras.layers.Input(shape=(5, 56, 56, 3))
net_output = decoder2(student(net_input))
net = keras.models.Model(inputs=[net_input], outputs=net_output, name='frontend')

# %%
# Example of low resolution frames creation
img = img = keras.layers.Resizing(224, 224, interpolation='bilinear', crop_to_aspect_ratio=False,)(cutims[5]).numpy()

frames_ten = preprocess_image_drc(tf.convert_to_tensor(img,dtype=tf.float32), img.shape[0], 56, is_training=False,teacher_mode=False, **drc_args)
frames_array = frames_ten[0].numpy()
frames_array.shape
plt.imshow(img.astype(int), vmin=0, vmax=255)
fig, axs = plt.subplots(1,frames_array.shape[0], figsize=(12, 6))
for i, ax in enumerate(axs.flat):
    ax.imshow(frames_array[i].astype(int), vmin=0, vmax=255)

# %%
# DRC
def preds_from_batches(layer_to_eval, data, batch_size = 64, sample_size=-1, time_mode='mean', drc_args={}):
    """
    Sasha's function for CNN application with a DRC layer. Processing each layer and saving the output
    """
    data_len = data.shape[0]
    samples_set_flag=False

    for batch in range(data_len//batch_size):
        start = batch * batch_size
        end = min((batch + 1)*batch_size, data_len)
        result = layer_to_eval(preprocess_for_drc_batch(data[start:end], **drc_args)) # <------
        result = result.numpy()
        if np.ndim(result) == 5:
            if time_mode == 'mean':
                result = result.mean(axis=1)
            else:
                error
        result = result.reshape([end-start,-1])
        if not samples_set_flag and sample_size > 0:
            samples = np.random.choice(result.shape[-1],sample_size)
            samples_set_flag = True
        if batch == 0:
            ll_out = np.zeros([data_len, result.shape[-1]]) if sample_size == -1 else np.zeros([data_len, sample_size])
        ll_out[start:end, :] = result if sample_size == -1 else result[:, samples]
    return ll_out

# %%
def corr_list_extractor(RDM_net, RDM_fmri, corr_fun=spearmanr):
    """
    This function takes all RDMs from all network layers, and all RDMS from FMRI voxels and calculate correlations.
    """
    corr_dict = {}
    for brain_area in RDM_fmri.keys():
        corr_dict[brain_area] = []
        for cnn_layer in range(len(RDM_net)):
            sz=RDM_net[cnn_layer].shape[0]
            mask = np.triu(np.ones([sz,sz],dtype=np.bool),1)
            corr, pval = corr_fun(np.nan_to_num(RDM_net[cnn_layer][mask]),RDM_fmri[brain_area][mask])
            corr_dict[brain_area].append(corr)
    print ("done correlations ")
    return corr_dict

# %%
net_lim

# %% [markdown]
# this is the level of the execution of the network. we can run the network as many times as we wish, changing the parameters of the pictures as desired.

# %%
# RDM of network layers
params_list = [pic_edit(net_size,0)]

RDM_net_sz={}
for params in params_list:
    RDM_net_sz[params] = {amp:{} for amp in amp_list}
    
for ll,layer in enumerate(student.layers + decoder2.layers): # layers of 2 networks
    print(ll, layer.name)
    
    # This is where we build an appropriate feature_extractor for each layer according to the net part it belongs with
    if ll<len(student.layers): # apply student
        feature_extractor = keras.Model(
           inputs=student.inputs,
           outputs=layer.output,
        )
    else: # apply decoder on the results of student
        decoder_model = keras.Model(inputs=decoder2.inputs, outputs = layer.output)
        input0 = keras.layers.Input(shape=(5, 56, 56, 3))
        stu_output = student(input0)
        dec_output = decoder_model(stu_output)
        net = keras.models.Model(inputs=[input0], outputs=dec_output, name='frontend')
        feature_extractor = keras.Model(
        inputs=input0,
        outputs=dec_output,
        )
    
    # here we apply the net's prediction of the particular layer
    for params in params_list:
        input_net = preprocss_net(net_size, cutims, params) # <- most probably resizing to 224*224
        for amp in amp_list:
            drc_args['amp'] = amp
            if ll == 0:
                print("applying network for images with params: \r\n image size:" + str(params.size) + 
                  " || blur filter size: "+ str(params.blur) + "\r\n amp frame: " + str(amp))
            activity = preds_from_batches(feature_extractor, input_net, # <---------
                                          batch_size=batch_size,
                                          sample_size=3000,
                                          time_mode='mean',
                                          drc_args=drc_args)
            RDM_net_sz[params][amp][ll] = 1-np.corrcoef(activity)
    del feature_extractor

# %% [markdown]
# # plots

# %% [raw]
# corr_dict = {sz : {amp : {key : corr_list_extractor(RDM_net_sz[sz][amp], RDM_fmri[key]) for key in RDM_fmri.keys()} for amp in amp_list}for sz in RDM_net_sz.keys()}

# %%
corr_dict = {sz : {amp : corr_list_extractor(RDM_net_sz[sz][amp], RDM_ecog) for amp in amp_list} for sz in RDM_net_sz.keys()}

# %%
corr_dict

# %% [raw]
# # Import regular data
# with open('/home/mor/NDS_project/results_202303261421/corr_dict.pkl', 'rb') as f:
#     cor_dict_vgg = pkl.load(f)
# cor_dict_vgg.keys()
#
# with open('/home/mor/NDS_project/results_data/sub1/Alexnet_results_202304131418/corr_dict.pkl', 'rb') as f:
#     cor_dict_alex = pkl.load(f)
# cor_dict_alex.keys()

# %% [raw]
# # Ploting comparing regular and DRC
# for amp in amp_list:
#     for area in corr_dict[list(corr_dict.keys())[0]][amp].keys():
#         fig, axs = plt.subplots(1,len(list(corr_dict.keys())) + 2, figsize=(12, 5),  sharex=True, sharey=True)
#         [axs[0].plot(corr_dict[list(corr_dict.keys())[0]][amp][area][roi], '*-') for roi in list(corr_dict[list(corr_dict.keys())[0]][amp][area].keys())]
#         [axs[1].plot(cor_dict_vgg[list(cor_dict_vgg.keys())[0]][area][roi], '*-') for roi in list(cor_dict_vgg[list(cor_dict_vgg.keys())[0]][area].keys())]
#         [axs[2].plot(cor_dict_alex[list(cor_dict_alex.keys())[0]][area][roi], '*-') for roi in list(cor_dict_alex[list(cor_dict_alex.keys())[0]][area].keys())]
#
#
#         axs[0].set_title("DRC net with amp = " + str(amp))
#         axs[1].set_title("Vgg16")
#         axs[2].set_title("Alexnet")
#         axs[0].set_ylabel("correlation")
#         axs[0].set_xlabel("layer number")
#         axs[1].set_xlabel("layer number")
#         axs[2].set_xlabel("layer number")
#
#         #     [ax2.plot(corr_dict[224][area][roi], '*-') for roi in corr_dict[224][area].keys()]
#         fig.legend(corr_dict[list(corr_dict.keys())[0]][amp][area].keys())
#         fig.suptitle("correlation for area: " + area + " || imsize: " + str(list(cor_dict_vgg.keys())[0].size), size=18)

# %%
colors = [axs[0].get_lines()[i].get_color() for i in range(len(list(axs[0].get_lines())))]
colors

# %% [markdown]
# # bootstrap

# %%
def resample(mat,mat_):
    ii = np.random.randint(mat.shape[0],size=(mat.shape[0]))
    not_diag = np.eye(*mat.shape)<1e-5
    return mat[:,ii][ii,:],mat_[:,ii][ii,:],not_diag[:,ii][ii,:]

# %%
def corr_list_extractor_resampled(RDM_net,RDM_fmri,corr_fun=spearmanr):
    """
    fOR BOOTSTRAP This function takes all RDMs from all network layers, and all RDMS from FMRI voxels and calculate correlations.
    """
    corr_dict = {}
    for brain_area in RDM_fmri.keys():
        corr_dict[brain_area] = []
        for cnn_layer in range(len(RDM_net)):
            sz=RDM_net[cnn_layer].shape[0]
            mask = np.triu(np.ones([sz,sz],dtype=np.bool),1)
            RDM1, RDM2, resample_mask = resample(RDM_net[cnn_layer],RDM_fmri[brain_area])
            mask = np.logical_and(mask, resample_mask)
            corr, pval = corr_fun(np.nan_to_num(RDM1[mask]),
                                  RDM2[mask])
            corr_dict[brain_area].append(corr)
        corr_dict[brain_area] = np.array(corr_dict[brain_area])#.reshape([2,-1])
    print ("done correlations ")
    return corr_dict

# %% [raw]
# n_resamples = 10
# corr_dict_vis = {samp: {sz : {amp : corr_list_extractor_resampled(RDM_net_sz[sz][amp], RDM_fmri['prf-visualrois']) for amp in amp_list} for sz in RDM_net_sz.keys()} for samp in range(n_resamples)}

# %%
n_resamples = 10
corr_dict_vis = {samp: {sz : {amp : corr_list_extractor_resampled(RDM_net_sz[sz][amp], RDM_ecog) for amp in amp_list} for sz in RDM_net_sz.keys()} for samp in range(n_resamples)}

# %% [raw]
# n_resamples = 10
# corr_dict_bodies = {samp: {sz : {amp : corr_list_extractor_resampled(RDM_net_sz[sz][amp], RDM_fmri['floc-bodies']) for amp in amp_list} for sz in RDM_net_sz.keys()} for samp in range(n_resamples)}

# %% [raw]
# corr_dict_bodies_all= {}
# for amp in amp_list:
#     corr_dict_bodies_all[amp] = {}
#     for area in corr_dict_bodies[0][list(corr_dict_bodies[0].keys())[0]][amp].keys():
#         corr_dict_bodies_all[amp][area] = []
#         for ii in range(n_resamples):
# #         print(corr_dict_vis[ii][list(corr_dict_vis[0].keys())[0]][amp])
#             corr_dict_bodies_all[amp][area].append(corr_dict_bodies[ii][list(corr_dict_bodies[0].keys())[0]][amp][area])
#         corr_dict_bodies_all[amp][area] = np.stack(corr_dict_bodies_all[amp][area])
# # corr_dict_vis_all['V1v'].shape
# # corr_dict_vis_all

# %%
corr_dict_vis_all= {}
for amp in amp_list:
    corr_dict_vis_all[amp] = {}
    for area in corr_dict_vis[0][list(corr_dict_vis[0].keys())[0]][amp].keys():
        corr_dict_vis_all[amp][area] = []
        for ii in range(n_resamples):
#         print(corr_dict_vis[ii][list(corr_dict_vis[0].keys())[0]][amp])
            corr_dict_vis_all[amp][area].append(corr_dict_vis[ii][list(corr_dict_vis[0].keys())[0]][amp][area])
        corr_dict_vis_all[amp][area] = np.stack(corr_dict_vis_all[amp][area])
# corr_dict_vis_all['V1v'].shape
# corr_dict_vis_all

# %% [raw]
# # ll=0
# for amp in corr_dict_vis_all.keys():
#     for i, key in enumerate(corr_dict_vis_all[amp].keys()):
#         x_vec = [uu for uu in range(corr_dict_vis_all[amp][key].shape[-1]) ]
#         plt.figure()
#         plt.errorbar(x_vec, corr_dict_vis_all[amp][key].mean(axis=0),
#                      yerr=corr_dict_vis_all[amp][key].std(axis=0), color = colors[i])
#         plt.title("amp= " + str(amp) + "|| ROI= "+ key)

# %% [raw]
# for amp in corr_dict_vis_all.keys():
#     for i, key in enumerate(corr_dict_vis_all[amp].keys()):
#         x_vec = [uu for uu in range(corr_dict_vis_all[amp]['V1v'].shape[-1])]
#         plt.figure()
#         # plt.errorbar(corr_mat70_all.mean(axis=0).T,corr_mat70_all.std(axis=0).T)
#         # plt.plot(corr_mat70_all.mean(axis=0).T)
#         # plt.plot(corr_mat70_all.std(axis=0).T)
#         plt.plot(x_vec,
#                      corr_dict_vis_all[amp][key].mean(axis=0), color = colors[i])
#         plt.fill_between(x_vec,
#                      corr_dict_vis_all[amp][key].mean(axis=0)-corr_dict_vis_all[amp][key].std(axis=0),
#                         corr_dict_vis_all[amp][key].mean(axis=0)+corr_dict_vis_all[amp][key].std(axis=0),alpha=0.4, color = colors[i])
#         plt.title("amp= " + str(amp) + "|| ROI= "+ key)

# %% [raw]
# for amp in corr_dict_bodies_all.keys():
#     for i, key in enumerate(corr_dict_bodies_all[amp].keys()):
#         x_vec = [uu for uu in range(corr_dict_bodies_all[amp]['EBA'].shape[-1])]
#         plt.figure()
#         # plt.errorbar(corr_mat70_all.mean(axis=0).T,corr_mat70_all.std(axis=0).T)
#         # plt.plot(corr_mat70_all.mean(axis=0).T)
#         # plt.plot(corr_mat70_all.std(axis=0).T)
#         plt.plot(x_vec,
#                      corr_dict_bodies_all[amp][key].mean(axis=0), color = colors[i])
#         plt.fill_between(x_vec,
#                      corr_dict_bodies_all[amp][key].mean(axis=0)-corr_dict_bodies_all[amp][key].std(axis=0),
#                         corr_dict_bodies_all[amp][key].mean(axis=0)+corr_dict_bodies_all[amp][key].std(axis=0),alpha=0.4, color = colors[i])
#         plt.title("amp= " + str(amp) + "|| ROI= "+ key)

# %%
# corr_dict_bodies_all[0]['EBA'].shape

# %% [markdown]
# # Saving the results

# %%
run_time = datetime.now().strftime("%Y%m%d%H%M")
run_time

path_for_save = "/home/mor/NDS_project/results_data/sub"+str(sub)+"/results_DRC_" + run_time
path_for_save = '/home/mor/ECoG/subjects_data/results/DRC_' + run_time

# Check whether the specified path exists or not
if not os.path.exists(path_for_save):
   # Create a new directory because it does not exist
   os.makedirs(path_for_save)
   print("The new directory "+ path_for_save +" is created!")

with open(path_for_save + '/corr_dict.pkl', 'wb') as handle:
    pkl.dump(corr_dict, handle, protocol=pkl.HIGHEST_PROTOCOL)
    print("saved corr_dict!")
    
with open(path_for_save + '/RDM_net_sz.pkl', 'wb') as handle:
    pkl.dump(RDM_net_sz, handle, protocol=pkl.HIGHEST_PROTOCOL)
    print("saved RDM_net_sz!")
    
    
with open(path_for_save + '/corr_dict_vis_all.pkl', 'wb') as handle:
    pkl.dump(corr_dict_vis_all, handle, protocol=pkl.HIGHEST_PROTOCOL)
    print("saved corr_dict_vis_all!")

# with open(path_for_save + '/corr_dict_bodies_all.pkl', 'wb') as handle:
#     pkl.dump(corr_dict_bodies_all, handle, protocol=pkl.HIGHEST_PROTOCOL)
#     print("saved corr_dict_bodies_all!")
    
with open(path_for_save + '/results_explained.txt', 'a') as f:
    f.write("Subject number: " + str(sub))
    f.write(input() + '\n')

# %%
path_for_save

# %%
# with open(path_for_save + '/results_explained1.txt', 'a') as f:
#     f.write("Subject number: " + str(sub))
#     f.write("\nRandom weights & DRC layer\n")
#     f.write(input() + '\n')

# %%
with open(path + '/voxels_ROIs.pkl', 'rb') as f:
    voxels_ROIs_s1_original = pkl.load(f)
voxels_ROIs_s1_original.keys()

# %% [markdown]
# ### Data categories

# %% [raw]
# # loding image metadata to find categories
# cat_path = "/home/mor/annotations_trainval2017/annotations/"
# fname = "instances_train2017"
# f = open(cat_path + fname +'.json', "r")
# data = json.loads(f.read())
#
# imid = data['annotations'][0]['image_id']
# imcat = data['annotations'][0]['category_id']
# data.keys()
# print([cat['name']  for cat in data['categories'] if cat['id'] == imcat])
# # catname = [cat['name'] if cat['id'] == imcat for cat in data['categories']]
# # data['categories'][0]
# imid
#
# im1= plt.imread(path+"/train2017/train2017/000000" + str(imid) +".jpg")
# plt.imshow(im1)
