# %%
from import_data_utils import *
from AlexNet_keras_model import model
from scipy.stats import ttest_ind as ttest
# Out:
# 2023-11-14 16:47:14.047002: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-14 16:47:14.047355: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-14 16:47:14.047658: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-14 16:47:14.047955: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-14 16:47:14.073967: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-14 16:47:14.074291: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-14 16:47:14.074591: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-14 16:47:14.074884: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-14 16:47:14.075178: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-14 16:47:14.075466: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-14 16:47:14.075754: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-14 16:47:14.076041: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-14 16:47:14.094873: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-14 16:47:14.095201: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-14 16:47:14.095497: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-14 16:47:14.491407: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-14 16:47:14.491760: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-14 16:47:14.492066: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-14 16:47:14.492329: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 42145 MB memory:  -> device: 3, name: NVIDIA RTX A6000, pci bus id: 0000:61:00.0, compute capability: 8.6
# Model: "Alex"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1 (Conv2D)               (None, 57, 57, 96)        34944
# _________________________________________________________________
# norm1 (Lambda)               (None, 57, 57, 96)        0
# _________________________________________________________________
# pool1 (MaxPooling2D)         (None, 28, 28, 96)        0
# _________________________________________________________________
# conv2 (Conv2D)               (None, 28, 28, 256)       307456
# _________________________________________________________________
# norm2 (Lambda)               (None, 28, 28, 256)       0
# _________________________________________________________________
# pool2 (MaxPooling2D)         (None, 13, 13, 256)       0
# _________________________________________________________________
# conv3 (Conv2D)               (None, 13, 13, 384)       885120
# _________________________________________________________________
# conv4 (Conv2D)               (None, 13, 13, 384)       663936
# _________________________________________________________________
# conv5 (Conv2D)               (None, 13, 13, 256)       442624
# _________________________________________________________________
# pool5 (MaxPooling2D)         (None, 6, 6, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 9216)              0
# _________________________________________________________________
# fc6 (Dense)                  (None, 4096)              37752832
# _________________________________________________________________
# fc7 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# fc8 (Dense)                  (None, 1000)              4097000
# _________________________________________________________________
# prob (Softmax)               (None, 1000)              0
# =================================================================
# Total params: 60,965,224
# Trainable params: 60,965,224
# Non-trainable params: 0
# _________________________________________________________________

# %%
def one_side_t_test(x,y):
    t_stat, p_val = ttest(y,x,equal_var = False)
    one_sided_p_val = p_val / 2
    print(t_stat,p_val)
    # For a test where you expect group1 to have a smaller mean than group2
    if t_stat < 0:
        one_sided_p_val = 1 - one_sided_p_val
    return one_sided_p_val

# %%
#VGG
with open('/home/mor/ECoG/subjects_data/results/DRC_202311081439/corr_dict_vis_all.pkl', 'rb') as f:
    corr_dict_vis_all_drc = pkl.load(f)
    
    
with open('/home/mor/ECoG/subjects_data/results/FF_202311081433/corr_dict_vis_all.pkl', 'rb') as f:
    corr_dict_vis_all_vgg = pkl.load(f)
corr_dict_vis_all_vgg['V1'].shape
# Out:
# (10, 23)

# %%
np.mean(corr_dict_vis_all_drc[0]['V1'][:,8])
# Out:
# 0.16828152201183025

# %%
gap = 1
amplist = ['DRC amp ' + str(amp) for amp in corr_dict_vis_all_drc.keys()]
amplist.insert(0,'FF')
alpha = 0.05  # significance level
alpha_1 = 0.01

for key in corr_dict_vis_all_vgg.keys():
    cor = np.zeros([len(list(corr_dict_vis_all_drc.keys())) + 1, corr_dict_vis_all_vgg[key].shape[1]]) # (ff+all amps) * network layers
    sd = np.zeros_like(cor)
    cor[0] = np.mean(corr_dict_vis_all_vgg[key], axis=0) # mean over all resamples for each layer FF
    sd[0] = np.std(corr_dict_vis_all_vgg[key], axis=0) # sd over all resamples for each layer FF
    for i, amp in enumerate(corr_dict_vis_all_drc.keys()):
        cor[i+1] = np.mean(corr_dict_vis_all_drc[amp][key][:,gap:], axis=0) # DRC - mean over all resamples for each layer
        sd[i+1] = np.std(corr_dict_vis_all_drc[amp][key][:,gap:], axis=0) # DRC -sd over all resamples for each layer

    plt.figure(figsize=(10,6))
    plt.imshow(cor)
    plt.title("VGG | ECoG | ROI "+ key +" - Correlation value as a function of \n amplitude and network layer ")
    plt.yticks(np.arange(0,7), amplist)
    plt.xlabel('network layer')
    cbar = plt.colorbar(orientation='vertical')
    plt.savefig("/home/mor/ECoG/results_data/figs/General/GBL_dist10/VGG_image_ROI_"+ key)    

    plt.figure(figsize=(10,6))
    max_cor = np.max(cor, axis=1) # the maximum correlated layer for each network condition (FF+ all amps)
    max_cor_arg = [np.argmax(cor, axis=1)[i] for i in range(max_cor.shape[0])] # the *ARG*maximum correlated layer for each network condition (FF+ all amps)
    max_cor_sd = [sd[i,np.argmax(cor, axis=1)[i]] for i in range(sd.shape[0])] # the SD for each max correlated layer for each condition
    max_cor_ff = corr_dict_vis_all_vgg[key][:,max_cor_arg[0]] # The correlation samples for the mex correlated layer for FF
    max_cor_amp = [corr_dict_vis_all_drc[amp][key][:,max_cor_arg[i+1]+gap] for i,amp in enumerate(corr_dict_vis_all_drc.keys())] # The correlation samples for the mex correlated layer for each amp
    pvalues = [one_side_t_test(max_cor_ff, max_cor_amp[i]) for i in range(len(max_cor_amp))]
    bars = plt.bar(np.arange(0,7), max_cor, yerr=max_cor_sd, zorder=1)
    x_coords = [bar.get_x() + bar.get_width() / 2 for bar in bars]
#     plt.scatter(x_coords, np.ones(len(x_coords)) * max_cor[0], c='r', zorder=2, label='FF correlation level') 
    bars[0].set_color('skyblue')
    for i in range(6):
        if pvalues[i] < alpha_1/10:
            plt.text(i+1.05, max_cor[i+1]+0.05, '***', c='purple')
        elif pvalues[i] < alpha_1:
            plt.text(i+1.05, max_cor[i+1]+0.05, '**', c='g')
        elif pvalues[i] < alpha:
            plt.text(i+1.05, max_cor[i+1]+0.05, '*', c='r')
        elif pvalues[i] < alpha*2:
            plt.text(i+1.05, max_cor[i+1]+0.05, '†', c='darkorange')
            
    plt.xticks(np.arange(0,7), amplist,rotation = 90)
    plt.xlabel('amplitude')
    plt.ylabel('Correlation')
    plt.title("VGG | ECoG | ROI "+ key +"- \n best Correlated value as a function of amplitude ")
    plt.legend()
    plt.savefig("/home/mor/ECoG/results_data/figs/General/GBL_dist10/VGG_bar_ROI_"+ key)    
    plt.show()
# Out:
# No handles with labels found to put in legend.
# 1.2583428740492706 0.22719535751750924
# 1.3512990707123704 0.1947442366447555
# 0.6327661646605813 0.5356567027234562
# 3.4965317530466478 0.0031885756201269727
# 1.4516906581383462 0.16667690624264128
# 2.752254348892504 0.01588044260208156
# No handles with labels found to put in legend.
# 0.6686518533552178 0.5125039741882889
# -0.23331402957948902 0.8185136356643353
# 0.06228478089939907 0.9510234531474292
# 0.30271651524602833 0.7655970699088674
# 0.11639380530896187 0.9086548604512598
# 1.1815219296010164 0.25330422772461303

# %%
#ALEX
with open('/home/mor/ECoG/subjects_data/results/Alexnet/DRC/DRC_202311081307/corr_dict_vis_all.pkl', 'rb') as f:
    corr_dict_vis_all_drc = pkl.load(f)
    
    
with open('/home/mor/ECoG/subjects_data/results/Alexnet/FF/FF_202311081310/corr_dict_vis_all.pkl', 'rb') as f:
    corr_dict_vis_all_vgg = pkl.load(f)

# %%
gap = 5
amplist = ['DRC amp ' + str(amp) for amp in corr_dict_vis_all_drc.keys()]
amplist.insert(0,'FF')
alpha = 0.05  # significance level
alpha_1 = 0.01

for key in corr_dict_vis_all_vgg.keys():
    cor = np.zeros([len(list(corr_dict_vis_all_drc.keys())) + 1, corr_dict_vis_all_vgg[key].shape[1]])
    sd = np.zeros_like(cor)
    cor[0] = np.mean(corr_dict_vis_all_vgg[key], axis=0)
    sd[0] = np.std(corr_dict_vis_all_vgg[key], axis=0)
    for i, amp in enumerate(corr_dict_vis_all_drc.keys()):
        cor[i+1] = np.mean(corr_dict_vis_all_drc[amp][key][:,gap:], axis=0)
        sd[i+1] = np.std(corr_dict_vis_all_drc[amp][key][:,gap:], axis=0)

    plt.figure(figsize=(10,6))
    plt.imshow(cor)
    plt.title("Alexnet | ECoG | ROI "+ key +" - Correlation value as a function of \n amplitude and network layer ")
    plt.yticks(np.arange(0,7), amplist)
    plt.xticks(range(corr_dict_vis_all_vgg[key].shape[1]), [(i, l.name) for i,l in enumerate(model.layers)],rotation = 90)
    plt.xlabel('network layer')
    cbar = plt.colorbar(orientation='vertical')
    plt.savefig("/home/mor/ECoG/results_data/figs/General/GBL_dist10/Alexnet_image_ROI_"+ key)    
   
    plt.figure(figsize=(10,6))
    max_cor = np.max(cor, axis=1) # the maximum correlated layer for each network condition (FF+ all amps)
    max_cor_arg = [np.argmax(cor, axis=1)[i] for i in range(max_cor.shape[0])] # the *ARG*maximum correlated layer for each network condition (FF+ all amps)
    max_cor_sd = [sd[i,np.argmax(cor, axis=1)[i]] for i in range(sd.shape[0])] # the SD for each max correlated layer for each condition
    max_cor_ff = corr_dict_vis_all_vgg[key][:,max_cor_arg[0]] # The correlation samples for the mex correlated layer for FF
    max_cor_amp = [corr_dict_vis_all_drc[amp][key][:,max_cor_arg[i+1]+gap] for i,amp in enumerate(corr_dict_vis_all_drc.keys())] # The correlation samples for the mex correlated layer for each amp
    pvalues = [one_side_t_test(max_cor_ff, max_cor_amp[i]) for i in range(len(max_cor_amp))]

    bars = plt.bar(np.arange(0,7), max_cor, yerr=max_cor_sd, zorder=1)
    x_coords = [bar.get_x() + bar.get_width() / 2 for bar in bars]
#     plt.scatter(x_coords, np.ones(len(x_coords)) * max_cor[0], c='r', zorder=2, label='FF correlation level') 
    
    for i in range(6):
        if pvalues[i] < alpha_1/10:
            plt.text(i+1.05, max_cor[i+1]+0.05, '***', c='purple')
        elif pvalues[i] < alpha_1:
            plt.text(i+1.05, max_cor[i+1]+0.05, '**', c='g')
        elif pvalues[i] < alpha:
            plt.text(i+1.05, max_cor[i+1]+0.05, '*', c='r')
        elif pvalues[i] < alpha*2:
            plt.text(i+1.05, max_cor[i+1]+0.05, '†', c='darkorange')
    bars[0].set_color('skyblue')
    plt.xticks(np.arange(0,7), amplist,rotation = 90)
    plt.xlabel('amplitude')
    plt.ylabel('Correlation')
    plt.title("Alexnet | ECoG | ROI "+ key +"- \n best Correlated value as a function of amplitude ")
    plt.legend()
    plt.savefig("/home/mor/ECoG/results_data/figs/General/GBL_dist10/Alexnet_bar_ROI_"+ key)    
    plt.show()
# Out:
# No handles with labels found to put in legend.
# 0.3483744596669741 0.7316188607117786
# -0.7332092834660124 0.4730463821248474
# 1.542630806209328 0.14069976666003559
# 2.1487705627577456 0.04550988505472617
# 5.656847625021727 4.170429922938468e-05
# 5.16675574033392 0.00012339150252035726
# No handles with labels found to put in legend.
# 2.7270973057338304 0.014400105569421525
# 3.5188051128053774 0.002724658127849525
# 2.7671661814303556 0.014355128674606815
# 0.7707598555469576 0.4515475352111069
# 3.0670908816251976 0.006890650034514446
# 2.945238665722292 0.008973096662758407

# %%
plt.scatter(np.arange(0,6), np.ones(6)*max_cor[0])

# %%
amplist = ['DRC amp ' + str(amp) for amp in corr_dict_vis_all_drc.keys()]
['FF'].extend(amplist)
amplist.insert(0,'FF')
amplist
# Out:
# ['FF',
#  'DRC amp 0',
#  'DRC amp 2',
#  'DRC amp 4',
#  'DRC amp 12',
#  'DRC amp 18',
#  'DRC amp 27']

# %%
max_cor = np.max(cor, axis=1)
plt.plot(max_cor)
plt.xticks(np.arange(0,7), amplist,rotation = 90)
plt.show()

# %%
# T test
ttest(corr_dict_vis_all_vgg['V1'], corr_dict_vis_all_drc[0]['V1'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_4223/628899352.py in <module>
#       1 # T test
# ----> 2 ttest(corr_dict_vis_all_vgg['V1'], corr_dict_vis_all_drc[0]['V1'])
#
# /usr/local/lib/python3.8/dist-packages/scipy/stats/stats.py in ttest_ind(a, b, axis, equal_var, nan_policy)
#    5258
#    5259     if equal_var:
# -> 5260         df, denom = _equal_var_ttest_denom(v1, n1, v2, n2)
#    5261     else:
#    5262         df, denom = _unequal_var_ttest_denom(v1, n1, v2, n2)
#
# /usr/local/lib/python3.8/dist-packages/scipy/stats/stats.py in _equal_var_ttest_denom(v1, n1, v2, n2)
#    5020 def _equal_var_ttest_denom(v1, n1, v2, n2):
#    5021     df = n1 + n2 - 2.0
# -> 5022     svar = ((n1 - 1) * v1 + (n2 - 1) * v2) / df
#    5023     denom = np.sqrt(svar * (1.0 / n1 + 1.0 / n2))
#    5024     return df, denom
#
# ValueError: operands could not be broadcast together with shapes (15,) (20,)

# %%
corr_dict_vis_all_drc[0]['V1'].shape

# %%
max_cor
max_cor_arg = [np.argmax(cor, axis=1)[i] for i in range(max_cor.shape[0])]
max_cor_amp = [corr_dict_vis_all_drc[key]['V2'][:,max_cor_arg[i]] for i,key in enumerate(corr_dict_vis_all_drc.keys())]
max_cor_ff = corr_dict_vis_all_vgg['V2'][:,max_cor_arg[0]]

# %%
max_cor_amp

# %%
a = [ttest(max_cor_ff, max_cor_amp[i]).pvalue for i in range(len(max_cor_amp))]
a
