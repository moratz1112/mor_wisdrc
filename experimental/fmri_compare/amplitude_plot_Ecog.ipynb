# %%
from import_data_utils import *
from AlexNet_keras_model import model
from scipy.stats import ttest_ind as ttest
# Out:
# 2023-11-15 12:29:07.411253: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-15 12:29:07.411569: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-15 12:29:07.411841: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-15 12:29:07.412107: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-15 12:29:07.435611: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-15 12:29:07.435897: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-15 12:29:07.436164: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-15 12:29:07.436427: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-15 12:29:07.436690: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-15 12:29:07.436956: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-15 12:29:07.437231: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-15 12:29:07.437510: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-15 12:29:07.455540: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-15 12:29:07.455861: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-15 12:29:07.456153: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-15 12:29:07.815223: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-15 12:29:07.815531: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-15 12:29:07.815796: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1050] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-15 12:29:07.816031: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 45024 MB memory:  -> device: 3, name: NVIDIA RTX A6000, pci bus id: 0000:61:00.0, compute capability: 8.6
# Model: "Alex"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1 (Conv2D)               (None, 57, 57, 96)        34944
# _________________________________________________________________
# norm1 (Lambda)               (None, 57, 57, 96)        0
# _________________________________________________________________
# pool1 (MaxPooling2D)         (None, 28, 28, 96)        0
# _________________________________________________________________
# conv2 (Conv2D)               (None, 28, 28, 256)       307456
# _________________________________________________________________
# norm2 (Lambda)               (None, 28, 28, 256)       0
# _________________________________________________________________
# pool2 (MaxPooling2D)         (None, 13, 13, 256)       0
# _________________________________________________________________
# conv3 (Conv2D)               (None, 13, 13, 384)       885120
# _________________________________________________________________
# conv4 (Conv2D)               (None, 13, 13, 384)       663936
# _________________________________________________________________
# conv5 (Conv2D)               (None, 13, 13, 256)       442624
# _________________________________________________________________
# pool5 (MaxPooling2D)         (None, 6, 6, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 9216)              0
# _________________________________________________________________
# fc6 (Dense)                  (None, 4096)              37752832
# _________________________________________________________________
# fc7 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# fc8 (Dense)                  (None, 1000)              4097000
# _________________________________________________________________
# prob (Softmax)               (None, 1000)              0
# =================================================================
# Total params: 60,965,224
# Trainable params: 60,965,224
# Non-trainable params: 0
# _________________________________________________________________

# %%
def one_side_t_test(x,y):
    t_stat, p_val = ttest(y,x,equal_var = False)
    one_sided_p_val = p_val / 2
    # For a test where you expect group1 to have a smaller mean than group2
    if t_stat < 0:
        one_sided_p_val = 1 - one_sided_p_val
    return one_sided_p_val

# %%
#VGG
with open('/home/mor/ECoG/subjects_data/results/DRC_202311081439/corr_dict_vis_all.pkl', 'rb') as f:
    corr_dict_vis_all_drc = pkl.load(f)
    
    
with open('/home/mor/ECoG/subjects_data/results/FF_202311081433/corr_dict_vis_all.pkl', 'rb') as f:
    corr_dict_vis_all_vgg = pkl.load(f)
corr_dict_vis_all_vgg['V1'].shape
# Out:
# (10, 23)

# %%
np.mean(corr_dict_vis_all_drc[0]['V1'][:,8])
# Out:
# 0.16828152201183025

# %%
gap = 1
amplist = [str(amp) for amp in corr_dict_vis_all_drc.keys()]
amplist.insert(0,'FF')
alpha = 0.05  # significance level
alpha_1 = 0.01

for key in corr_dict_vis_all_vgg.keys():
    cor = np.zeros([len(list(corr_dict_vis_all_drc.keys())) + 1, corr_dict_vis_all_vgg[key].shape[1]]) # (ff+all amps) * network layers
    sd = np.zeros_like(cor)
    cor[0] = np.mean(corr_dict_vis_all_vgg[key], axis=0) # mean over all resamples for each layer FF
    sd[0] = np.std(corr_dict_vis_all_vgg[key], axis=0) # sd over all resamples for each layer FF
    for i, amp in enumerate(corr_dict_vis_all_drc.keys()):
        cor[i+1] = np.mean(corr_dict_vis_all_drc[amp][key][:,gap:], axis=0) # DRC - mean over all resamples for each layer
        sd[i+1] = np.std(corr_dict_vis_all_drc[amp][key][:,gap:], axis=0) # DRC -sd over all resamples for each layer

    plt.figure(figsize=(10,8))
    plt.imshow(cor)
    plt.title("VGG | ECoG | ROI "+ key +" - Correlation value as a function of \n amplitude and network layer ", size=16)
    plt.yticks(np.arange(0,7), amplist)
    plt.xlabel('network layer')
    cbar = plt.colorbar(orientation='vertical')
    plt.savefig("/home/mor/ECoG/results_data/figs/General/GBL_dist10/VGG_image_ROI_"+ key)    

    plt.figure(figsize=(10,8))
    max_cor = np.max(cor, axis=1) # the maximum correlated layer for each network condition (FF+ all amps)
    max_cor_arg = [np.argmax(cor, axis=1)[i] for i in range(max_cor.shape[0])] # the *ARG*maximum correlated layer for each network condition (FF+ all amps)
    max_cor_sd = [sd[i,np.argmax(cor, axis=1)[i]] for i in range(sd.shape[0])] # the SD for each max correlated layer for each condition
    max_cor_ff = corr_dict_vis_all_vgg[key][:,max_cor_arg[0]] # The correlation samples for the mex correlated layer for FF
    max_cor_amp = [corr_dict_vis_all_drc[amp][key][:,max_cor_arg[i+1]+gap] for i,amp in enumerate(corr_dict_vis_all_drc.keys())] # The correlation samples for the mex correlated layer for each amp
    pvalues = [one_side_t_test(max_cor_ff, max_cor_amp[i]) for i in range(len(max_cor_amp))]
    bars = plt.bar(np.arange(0,7), max_cor, yerr=max_cor_sd, zorder=1)
    x_coords = [bar.get_x() + bar.get_width() / 2 for bar in bars]
#     plt.scatter(x_coords, np.ones(len(x_coords)) * max_cor[0], c='r', zorder=2, label='FF correlation level') 
    bars[0].set_color('skyblue')
    for i in range(6):
        if pvalues[i] < alpha_1/10:
            plt.text(i+1.05, max_cor[i+1]+0.05, '***', c='purple', size=12)
        elif pvalues[i] < alpha_1:
            plt.text(i+1.05, max_cor[i+1]+0.05, '**', c='g', size=12)
        elif pvalues[i] < alpha:
            plt.text(i+1.05, max_cor[i+1]+0.05, '*', c='r', size=12)
        elif pvalues[i] < alpha*2:
            plt.text(i+1.05, max_cor[i+1]+0.05, '†', c='darkorange', size=12)
    plt.yticks(size=12)    
    plt.xticks(np.arange(0,7), amplist, size=12)
    plt.xlabel('amplitude', size=12)
    plt.ylabel('Correlation', size=12)
    plt.title("VGG | ECoG | ROI "+ key +"- \n best Correlated value as a function of amplitude" , size=16)
    plt.legend()
    plt.savefig("/home/mor/ECoG/results_data/figs/General/GBL_dist10/VGG_bar_ROI_"+ key)    
    plt.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
#ALEX
with open('/home/mor/ECoG/subjects_data/results/Alexnet/DRC/DRC_202311081307/corr_dict_vis_all.pkl', 'rb') as f:
    corr_dict_vis_all_drc = pkl.load(f)
    
    
with open('/home/mor/ECoG/subjects_data/results/Alexnet/FF/FF_202311081310/corr_dict_vis_all.pkl', 'rb') as f:
    corr_dict_vis_all_vgg = pkl.load(f)

# %%
gap = 5
amplist = [str(amp) for amp in corr_dict_vis_all_drc.keys()]
amplist.insert(0,'FF')
alpha = 0.05  # significance level
alpha_1 = 0.01

for key in corr_dict_vis_all_vgg.keys():
    cor = np.zeros([len(list(corr_dict_vis_all_drc.keys())) + 1, corr_dict_vis_all_vgg[key].shape[1]])
    sd = np.zeros_like(cor)
    cor[0] = np.mean(corr_dict_vis_all_vgg[key], axis=0)
    sd[0] = np.std(corr_dict_vis_all_vgg[key], axis=0)
    for i, amp in enumerate(corr_dict_vis_all_drc.keys()):
        cor[i+1] = np.mean(corr_dict_vis_all_drc[amp][key][:,gap:], axis=0)
        sd[i+1] = np.std(corr_dict_vis_all_drc[amp][key][:,gap:], axis=0)

    plt.figure(figsize=(10,8))
    plt.imshow(cor)
    plt.title("Alexnet | ECoG | ROI "+ key +" - Correlation value as a function of \n amplitude and network layer ", size=16)
    plt.yticks(np.arange(0,7), amplist)
    plt.xticks(range(corr_dict_vis_all_vgg[key].shape[1]), [(i, l.name) for i,l in enumerate(model.layers)],rotation = 90)
    plt.xlabel('network layer')
    cbar = plt.colorbar(orientation='vertical')
    plt.savefig("/home/mor/ECoG/results_data/figs/General/GBL_dist10/Alexnet_image_ROI_"+ key)    
   
    plt.figure(figsize=(10,8))
    max_cor = np.max(cor, axis=1) # the maximum correlated layer for each network condition (FF+ all amps)
    max_cor_arg = [np.argmax(cor, axis=1)[i] for i in range(max_cor.shape[0])] # the *ARG*maximum correlated layer for each network condition (FF+ all amps)
    max_cor_sd = [sd[i,np.argmax(cor, axis=1)[i]] for i in range(sd.shape[0])] # the SD for each max correlated layer for each condition
    max_cor_ff = corr_dict_vis_all_vgg[key][:,max_cor_arg[0]] # The correlation samples for the mex correlated layer for FF
    max_cor_amp = [corr_dict_vis_all_drc[amp][key][:,max_cor_arg[i+1]+gap] for i,amp in enumerate(corr_dict_vis_all_drc.keys())] # The correlation samples for the mex correlated layer for each amp
    pvalues = [one_side_t_test(max_cor_ff, max_cor_amp[i]) for i in range(len(max_cor_amp))]

    bars = plt.bar(np.arange(0,7), max_cor, yerr=max_cor_sd, zorder=1)
    x_coords = [bar.get_x() + bar.get_width() / 2 for bar in bars]
#     plt.scatter(x_coords, np.ones(len(x_coords)) * max_cor[0], c='r', zorder=2, label='FF correlation level') 
    
    for i in range(6):
        if pvalues[i] < alpha_1/10:
            plt.text(i+1.05, max_cor[i+1]+0.05, '***', c='purple', size=12)
        elif pvalues[i] < alpha_1:
            plt.text(i+1.05, max_cor[i+1]+0.05, '**', c='g', size=12)
        elif pvalues[i] < alpha:
            plt.text(i+1.05, max_cor[i+1]+0.05, '*', c='r', size=12)
        elif pvalues[i] < alpha*2:
            plt.text(i+1.05, max_cor[i+1]+0.05, '†', c='darkorange', size=12)
    bars[0].set_color('skyblue')
    plt.xticks(np.arange(0,7), amplist, size=12)
    plt.yticks(size=12)
    plt.xlabel('amplitude', size=12)
    plt.ylabel('Correlation', size=12)
    plt.title("Alexnet | ECoG | ROI "+ key +"- \n best Correlated value as a function of amplitude ", size=16)
    plt.legend()
    plt.savefig("/home/mor/ECoG/results_data/figs/General/GBL_dist10/Alexnet_bar_ROI_"+ key)    
    plt.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
plt.scatter(np.arange(0,6), np.ones(6)*max_cor[0])

# %%
amplist = ['DRC amp ' + str(amp) for amp in corr_dict_vis_all_drc.keys()]
['FF'].extend(amplist)
amplist.insert(0,'FF')
amplist
# Out:
# ['FF',
#  'DRC amp 0',
#  'DRC amp 2',
#  'DRC amp 4',
#  'DRC amp 12',
#  'DRC amp 18',
#  'DRC amp 27']

# %%
max_cor = np.max(cor, axis=1)
plt.plot(max_cor)
plt.xticks(np.arange(0,7), amplist,rotation = 90)
plt.show()

# %%
# T test
ttest(corr_dict_vis_all_vgg['V1'], corr_dict_vis_all_drc[0]['V1'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_4329/628899352.py in <module>
#       1 # T test
# ----> 2 ttest(corr_dict_vis_all_vgg['V1'], corr_dict_vis_all_drc[0]['V1'])
#
# /usr/local/lib/python3.8/dist-packages/scipy/stats/stats.py in ttest_ind(a, b, axis, equal_var, nan_policy)
#    5258
#    5259     if equal_var:
# -> 5260         df, denom = _equal_var_ttest_denom(v1, n1, v2, n2)
#    5261     else:
#    5262         df, denom = _unequal_var_ttest_denom(v1, n1, v2, n2)
#
# /usr/local/lib/python3.8/dist-packages/scipy/stats/stats.py in _equal_var_ttest_denom(v1, n1, v2, n2)
#    5020 def _equal_var_ttest_denom(v1, n1, v2, n2):
#    5021     df = n1 + n2 - 2.0
# -> 5022     svar = ((n1 - 1) * v1 + (n2 - 1) * v2) / df
#    5023     denom = np.sqrt(svar * (1.0 / n1 + 1.0 / n2))
#    5024     return df, denom
#
# ValueError: operands could not be broadcast together with shapes (15,) (20,)

# %%
corr_dict_vis_all_drc[0]['V1'].shape

# %%
max_cor
max_cor_arg = [np.argmax(cor, axis=1)[i] for i in range(max_cor.shape[0])]
max_cor_amp = [corr_dict_vis_all_drc[key]['V2'][:,max_cor_arg[i]] for i,key in enumerate(corr_dict_vis_all_drc.keys())]
max_cor_ff = corr_dict_vis_all_vgg['V2'][:,max_cor_arg[0]]

# %%
max_cor_amp

# %%
a = [ttest(max_cor_ff, max_cor_amp[i]).pvalue for i in range(len(max_cor_amp))]
a
